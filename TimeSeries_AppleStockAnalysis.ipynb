# %% [markdown]
# <a href="https://colab.research.google.com/github/akakadem/Crystal_Reports/blob/main/TimeSeries_AppleStockAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_apple = pd.read_csv('/content/Apple_History_10Years.csv')

# %%
df_apple
# Out:
#             Date Close/Last     Volume      Open      High        Low
# 0     10/24/2025    $262.82   38253720   $261.19   $264.13    $259.18
# 1     10/23/2025    $259.58   32754940   $259.94   $260.62  $258.0101
# 2     10/22/2025    $258.45   45015250   $262.65   $262.85    $255.43
# 3     10/21/2025    $262.77   46695950   $261.88   $265.29    $261.83
# 4     10/20/2025    $262.24   90483030  $255.885  $264.375    $255.63
# ...          ...        ...        ...       ...       ...        ...
# 2510  10/30/2015    $29.875  197220880  $30.2475   $30.305   $29.8625
# 2511  10/29/2015   $30.1325  204424400   $29.675  $30.1725   $29.5675
# 2512  10/28/2015   $29.8175  341744840  $29.2325   $29.825    $29.015
# 2513  10/27/2015   $28.6375  270693800    $28.85   $29.135   $28.4975
# 2514  10/26/2015     $28.82  264559080    $29.52  $29.5325     $28.73
#
# [2515 rows x 6 columns]

# %%
df_apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2515 non-null   object
#  1   Close/Last  2515 non-null   object
#  2   Volume      2515 non-null   int64
#  3   Open        2515 non-null   object
#  4   High        2515 non-null   object
#  5   Low         2515 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 118.0+ KB

# %%
df_apple = pd.read_csv('/content/Apple_History_10Years.csv', parse_dates=['Date'])

# %%
df_apple = pd.read_csv('/content/Apple_History_10Years.csv', parse_float64=['Close/Last'])

# %%
df_apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2515 entries, 0 to 2514
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2515 non-null   object
#  1   Close/Last  2515 non-null   float64
#  2   Volume      2515 non-null   int64
#  3   Open        2515 non-null   object
#  4   High        2515 non-null   object
#  5   Low         2515 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 118.0+ KB

# %%
df_apple = pd.read_csv('/content/Apple_History_10Years.csv', parse_dates=['Date'], index_col='Date')
df_apple['Close/Last'] = df_apple['Close/Last'].str.replace('$', '', regex=False).astype(float)
df_apple['Open'] = df_apple['Open'].str.replace('$', '', regex=False).astype(float)
df_apple['High'] = df_apple['High'].str.replace('$', '', regex=False).astype(float)
df_apple['Low'] = df_apple['Low'].str.replace('$', '', regex=False).astype(float)
df_apple = df_apple.rename(columns={'Close/Last': 'Close'})

# %%
df_apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2515 entries, 2025-10-24 to 2015-10-26
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2515 non-null   float64
#  1   Volume  2515 non-null   int64
#  2   Open    2515 non-null   float64
#  3   High    2515 non-null   float64
#  4   Low     2515 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB

# %%
df_apple
# Out:
#                Close     Volume      Open      High       Low
# Date
# 2025-10-24  262.8200   38253720  261.1900  264.1300  259.1800
# 2025-10-23  259.5800   32754940  259.9400  260.6200  258.0101
# 2025-10-22  258.4500   45015250  262.6500  262.8500  255.4300
# 2025-10-21  262.7700   46695950  261.8800  265.2900  261.8300
# 2025-10-20  262.2400   90483030  255.8850  264.3750  255.6300
# ...              ...        ...       ...       ...       ...
# 2015-10-30   29.8750  197220880   30.2475   30.3050   29.8625
# 2015-10-29   30.1325  204424400   29.6750   30.1725   29.5675
# 2015-10-28   29.8175  341744840   29.2325   29.8250   29.0150
# 2015-10-27   28.6375  270693800   28.8500   29.1350   28.4975
# 2015-10-26   28.8200  264559080   29.5200   29.5325   28.7300
#
# [2515 rows x 5 columns]

# %%
# Data frame of Apple stock locate the data for July month in Year 2025
df_apple_indexed = df_apple.set_index('Date')
df_apple_indexed.loc['2025-07']
# Out:
#             Close/Last    Volume     Open      High       Low
# Date
# 2025-07-31      207.57  80698430  208.490  209.8400  207.1600
# 2025-07-30      209.05  45512510  211.895  212.3900  207.7200
# 2025-07-29      211.27  51411720  214.175  214.8100  210.8200
# 2025-07-28      214.05  37858020  214.030  214.8450  213.0600
# 2025-07-25      213.88  40268780  214.700  215.2400  213.4000
# 2025-07-24      213.76  46022620  213.900  215.6900  213.5300
# 2025-07-23      214.15  46989300  215.000  215.1500  212.4100
# 2025-07-22      214.40  46404070  213.140  214.9500  212.2301
# 2025-07-21      212.48  51377430  212.100  215.7800  211.6300
# 2025-07-18      211.18  48974590  210.870  211.7900  209.7045
# 2025-07-17      210.02  48068140  210.570  211.8000  209.5900
# 2025-07-16      210.16  47490530  210.295  212.4000  208.6400
# 2025-07-15      209.11  42296340  209.220  211.8900  208.9200
# 2025-07-14      208.62  38840110  209.925  210.9100  207.5400
# ...

# %%
# Data frame of Apple stock locate the data on 2024-06-05
df_apple_indexed = df_apple.set_index('Date')
df_apple_indexed.loc['2024-06-05']
# Out:
# Close/Last         195.87
# Volume        54156790.00
# Open               195.40
# High               196.90
# Low                194.87
# Name: 2024-06-05 00:00:00, dtype: float64

# %%
df_apple.loc['2024-06'].mean()
# Out:
# Close/Last    2.062632e+02
# Volume        9.073603e+07
# Open          2.059942e+02
# High          2.090363e+02
# Low           2.039202e+02
# dtype: float64

# %%
# Data frame of Apple stock - Average stock price for June month use mean formula
df_apple.loc['2017-06'].mean()
# Out:
# Close/Last    3.695784e+01
# Volume        1.240499e+08
# Open          3.705375e+01
# High          3.727215e+01
# Low           3.664568e+01
# dtype: float64

# %%
# Data frame of Apple stock locate the data for June month
df_apple.loc['2025-06']
# Out:
#              Close    Volume     Open     High       Low
# Date
# 2025-06-30  205.17  91912820  202.010  207.390  199.2607
# 2025-06-27  201.08  73188570  201.890  203.220  200.0000
# 2025-06-26  201.00  50799120  201.430  202.640  199.4600
# 2025-06-25  201.56  39525730  201.450  203.670  200.6201
# 2025-06-24  200.30  54064030  202.590  203.440  200.2000
# 2025-06-23  201.50  55814270  201.625  202.300  198.9600
# 2025-06-20  201.00  96813540  198.235  201.700  196.8550
# 2025-06-18  196.58  45394690  195.940  197.570  195.0700
# 2025-06-17  195.64  38856150  197.200  198.390  195.2100
# 2025-06-16  198.42  43020690  197.300  198.685  196.5636
# 2025-06-13  196.45  51447350  199.730  200.370  195.7000
# 2025-06-12  199.20  43904640  199.080  199.680  197.3601
# 2025-06-11  198.78  60989860  203.500  204.500  198.4100
# 2025-06-10  202.67  54672610  200.600  204.350  200.5700
# 2025-06-09  201.45  72862560  204.390  206.000  200.0200
# ...

# %%
df_apple.loc['2017-06'].Close.mean()
# Out:
# np.float64(36.9578409090909)

# %%
df_apple = df_apple.sort_index()

# %%
df_apple
# Out:
#                Close     Volume      Open      High       Low
# Date
# 2015-10-26   28.8200  264559080   29.5200   29.5325   28.7300
# 2015-10-27   28.6375  270693800   28.8500   29.1350   28.4975
# 2015-10-28   29.8175  341744840   29.2325   29.8250   29.0150
# 2015-10-29   30.1325  204424400   29.6750   30.1725   29.5675
# 2015-10-30   29.8750  197220880   30.2475   30.3050   29.8625
# ...              ...        ...       ...       ...       ...
# 2025-10-20  262.2400   90483030  255.8850  264.3750  255.6300
# 2025-10-21  262.7700   46695950  261.8800  265.2900  261.8300
# 2025-10-22  258.4500   45015250  262.6500  262.8500  255.4300
# 2025-10-23  259.5800   32754940  259.9400  260.6200  258.0101
# 2025-10-24  262.8200   38253720  261.1900  264.1300  259.1800
#
# [2515 rows x 5 columns]

# %%
df_apple.Close.resample('Y').mean()
# Out:
# /tmp/ipython-input-84695623.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df_apple.Close.resample('Y').mean()
# Date
# 2015-12-31     28.778536
# 2016-12-31     26.151002
# 2017-12-31     37.637764
# 2018-12-31     47.263357
# 2019-12-31     52.063983
# 2020-12-31     95.346759
# 2021-12-31    140.989325
# 2022-12-31    154.835060
# 2023-12-31    172.548960
# 2024-12-31    207.205913
# 2025-12-31    222.895294
# Freq: YE-DEC, Name: Close, dtype: float64

# %%
df_apple.Close.resample('Q').mean()
# Out:
# /tmp/ipython-input-806473956.py:1: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df_apple.Close.resample('Q').mean()
# Date
# 2015-12-31     28.778536
# 2016-03-31     24.913770
# 2016-06-30     24.850313
# 2016-09-30     26.466523
# 2016-12-31     28.349762
# 2017-03-31     32.928126
# 2017-06-30     36.968849
# 2017-09-30     38.792262
# 2017-12-31     41.787063
# 2018-03-31     43.047828
# 2018-06-30     45.349141
# 2018-09-30     52.075000
# 2018-12-31     48.478016
# 2019-03-31     42.415943
# 2019-06-30     48.723175
# 2019-09-30     52.280177
# 2019-12-31     64.332188
# 2020-03-31     73.540927
# 2020-06-30     77.490317
# 2020-09-30    109.114180
# 2020-12-31    120.281172
# 2021-03-31    128.357951
# 2021-06-30    129.568810
# 2021-09-30    147.222969
# 2021-12-31    158.037031
# 2022-03-31    168.163548
# 2022-06-30    151.439194
# 2022-09-30    156.950469
# 2022-12-31    142.911111
# 2023-03-31    147.551129
# ...

# %%
df_apple.Close.resample('M').mean()
# Out:
# /tmp/ipython-input-2493064388.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_apple.Close.resample('M').mean()
# Date
# 2015-10-31     29.456500
# 2015-11-30     29.540560
# 2015-12-31     27.931705
# 2016-01-31     24.607237
# 2016-02-29     23.936625
#                  ...
# 2025-06-30    200.657000
# 2025-07-31    211.280909
# 2025-08-31    224.647143
# 2025-09-30    242.486190
# 2025-10-31    255.083889
# Freq: ME, Name: Close, Length: 121, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df_apple.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Plotting the bar chart for monthly activities using resampled monthly averages. Easy to read and follow the chart
df_apple.Close.resample('M').mean().plot(kind = 'bar')
# Out:
# /tmp/ipython-input-2094466966.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_apple.Close.resample('M').mean().plot(kind = 'bar')
# <Axes: xlabel='Date'>

# %%
# plotting the bar chart for every day activities
df_apple.Close.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Date'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing

# %%
target = df_apple['Close']

# %%
target
# Out:
# Date
# 2015-10-26     28.8200
# 2015-10-27     28.6375
# 2015-10-28     29.8175
# 2015-10-29     30.1325
# 2015-10-30     29.8750
#                 ...
# 2025-10-20    262.2400
# 2025-10-21    262.7700
# 2025-10-22    258.4500
# 2025-10-23    259.5800
# 2025-10-24    262.8200
# Name: Close, Length: 2515, dtype: float64

# %%
len(target)
# Out:
# 2515

# %%
# Naive Model -> is Previous Day Prices

# %%
target.shift(1)
# Out:
# Date
# 2015-10-26         NaN
# 2015-10-27     28.8200
# 2015-10-28     28.6375
# 2015-10-29     29.8175
# 2015-10-30     30.1325
#                 ...
# 2025-10-20    252.2900
# 2025-10-21    262.2400
# 2025-10-22    262.7700
# 2025-10-23    258.4500
# 2025-10-24    259.5800
# Name: Close, Length: 2515, dtype: float64

# %%
naive_historical_fit = target.shift(1)

# %%
plt.figure(figsize=(12,6))
plt.plot(target.index, target, label='Actual Data')
plt.plot(target.index, naive_historical_fit, label='Naive Model')
plt.title('Apple Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.legend()
plt.grid('True')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ts_data = df_apple['Close']
len(ts_data)
# Out:
# 2515

# %%
naive_historical_fit = ts_data.shift(1)

# %%
plt.figure(figsize=(12,6))
plt.plot(ts_data.index, ts_data, label='Actual Data')
plt.plot(ts_data.index, naive_historical_fit, label='Naive Model')
plt.title('Apple Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.legend()
plt.grid('True')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Naive Model: Before the we looked at 10 years of data, however, we will watch not less than 10 days
plt.figure(figsize=(12,6))
plt.plot(ts_data.index[-10:], ts_data[-10:], label='Actual Data')
plt.plot(ts_data.index[-10:], naive_historical_fit[-10:], label='Naive Model')
plt.title('Apple Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.legend()
plt.grid('True')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Naive Model: Before the we looked at 10 years of data, however, we will watch not last 50 days
plt.figure(figsize=(12,6))
plt.plot(ts_data.index[-50:], ts_data[-50:], label='Actual Data')
plt.plot(ts_data.index[-50:], naive_historical_fit[-50:], label='Naive Model')
plt.title('Apple Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.legend()
plt.grid('True')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Naive Model: Before the we looked at 10 years of data, however, we will watch not last 200 days
plt.figure(figsize=(12,8))
plt.plot(ts_data.index[-200:], ts_data[-200:], label='Actual Data')
plt.plot(ts_data.index[-200:], naive_historical_fit[-200:], label='Naive Model')
plt.title('Apple Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Price($)')
plt.legend()
plt.grid('True')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
